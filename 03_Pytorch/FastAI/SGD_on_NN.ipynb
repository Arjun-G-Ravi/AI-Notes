# %%
import numpy as np
from fastai.vision.all import *
import matplotlib.pyplot as plt

# %%
time = torch.arange(0,40).float()

speed = torch.tensor([(i*i/100)*random.randint(8,12) for i in range(-20,20)])

speed
# Out:
# tensor([40.0000, 28.8800, 29.1600, 31.7900, 30.7200, 22.5000, 15.6800, 16.9000,
#         17.2800, 12.1000,  8.0000,  9.7200,  7.6800,  5.8800,  3.9600,  2.5000,
#          1.4400,  0.7200,  0.4400,  0.0900,  0.0000,  0.1100,  0.4000,  1.0800,
#          1.4400,  2.0000,  4.3200,  5.3900,  5.1200,  6.4800,  8.0000,  9.6800,
#         12.9600, 16.9000, 23.5200, 18.0000, 28.1600, 31.7900, 29.1600, 43.3200])

# %%
plt.scatter(time, speed)
plt.show()

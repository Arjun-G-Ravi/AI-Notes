# %% [markdown]
# Step 0

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
transform = transforms.ToTensor()
batch_size = 500
num_epoch = 50
lr = .0001
hidden_size1 = 300
hidden_size2 = 300
hidden_size3 = 300
hidden_size4 = 300

# %%
train_dataset = torchvision.datasets.CIFAR10('/home/arjun/Documents/DatasetCollection', train=True,transform=transform)
test_dataset =  torchvision.datasets.CIFAR10('/home/arjun/Documents/DatasetCollection', train=False,transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, shuffle=True, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_dataset, shuffle=False, batch_size=batch_size)

# %%
tot_steps = len(train_loader)  # Or the total number of batches

# One step is one batch calculation
tot_steps
# Out:
# 100

# %%
classes = ['plane', 'car', 'bird', 'cat','deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
for batch in train_loader:
    image, label = batch

(batch[0]).shape
# Out:
# torch.Size([500, 3, 32, 32])

# %%
# print(classes[label[0]])
# plt.imshow(image[0][0])
# plt.show()

# %%
for i in range(1,10):
    plt.subplot(3,3,i)
    plt.imshow(image[i][0])
    plt.ylabel(classes[label[i]])

# %% [markdown]
# Step 1

# %%
class CIFAR10_NN(nn.Module):
    def __init__(self, inp_size, hidden_size1, hidden_size2, hidden_size3, hidden_size4, out_size):
        super(CIFAR10_NN, self).__init__()
        self.lay1 = nn.Linear(inp_size, hidden_size1)
        self.lay2 = nn.ReLU()
        self.lay3 = nn.Linear(hidden_size1, hidden_size2)
        self.lay4 = nn.Linear(hidden_size2, hidden_size3)
        self.lay5 = nn.Linear(hidden_size3, hidden_size4)
        self.lay6 = nn.Linear(hidden_size4, out_size)
    def forward(self, X):
        out = self.lay1(X)  
        out = self.lay2(out)
        out = self.lay3(out)
        out = self.lay2(out)
        out = self.lay4(out)
        out = self.lay2(out)
        out = self.lay5(out)
        out = self.lay2(out)
        out = self.lay6(out)
        return out
    
model = CIFAR10_NN(32*32, hidden_size1, hidden_size2, hidden_size3, hidden_size4, 10).to(device)

# %% [markdown]
# Step 2

# %%
lossCat = nn.CrossEntropyLoss()
optimiser = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# Step 3

# %%
num_steps_in_a_batch = len(train_dataset)/batch_size
for epoch in range(num_epoch):
    for step, (images, labels) in enumerate(train_loader):
        images = images[:,1,:,:].reshape(batch_size,32*32).to(device)
        labels = labels.to(device)

        y_hat = model(images)
        loss = lossCat(y_hat, labels)
        loss.backward()
        optimiser.step()
        optimiser.zero_grad()

        if step == num_steps_in_a_batch - 1:
            print(f"Epoch {epoch+1}  Loss:{loss}")
# Out:
# Epoch 1  Loss:2.143622875213623
# Epoch 2  Loss:2.0523977279663086
# Epoch 3  Loss:1.99625563621521
# Epoch 4  Loss:1.9478918313980103
# Epoch 5  Loss:1.8833985328674316
# Epoch 6  Loss:1.8452719449996948
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 num_steps_in_a_batch = len(train_dataset)/batch_size
#       2 for epoch in range(num_epoch):
# ----> 3     for step, (images, labels) in enumerate(train_loader):
#       4         images = images[:,1,:,:].reshape(batch_size,32*32).to(device)
#       5         labels = labels.to(device)
#
# File ~/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:671, in _SingleProcessDataLoaderIter._next_data(self)
#     669 def _next_data(self):
#     670     index = self._next_index()  # may raise StopIteration
# --> 671     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672     if self._pin_memory:
#     673         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/.local/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:58, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# File ~/.local/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:58, in <listcomp>(.0)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# File ~/.local/lib/python3.10/site-packages/torchvision/datasets/cifar.py:115, in CIFAR10.__getitem__(self, index)
#     111 img, target = self.data[index], self.targets[index]
#     113 # doing this so that it is consistent with all other datasets
#     114 # to return a PIL Image
# --> 115 img = Image.fromarray(img)
#     117 if self.transform is not None:
#     118     img = self.transform(img)
#
# File /usr/lib/python3/dist-packages/PIL/Image.py:2830, in fromarray(obj, mode)
#    2828 if strides is not None:
#    2829     if hasattr(obj, "tobytes"):
# -> 2830         obj = obj.tobytes()
#    2831     else:
#    2832         obj = obj.tostring()
#
# KeyboardInterrupt:

# %% [markdown]
# Step 4

# %%
# print(len(train_loader))
with torch.no_grad():
    tot_sample, correct_sample = 0,0
    for sample, target in test_loader:  
            sample = sample[:,1,:,:].resize(batch_size, 32*32).to(device)
            target = target.to(device)

            out = model(sample)
            _, prediction = torch.max(out,1)
            # print(target)
            # print(prediction)
            # print()
            
            tot_sample += batch_size
            correct_sample += ((prediction == target).sum()).item()

# %%
print(f"Accuracy = {(correct_sample/tot_sample)*100:.3f}")
# Out:
# Accuracy = 32.300

# %% [markdown]
# Best Accuracy = 44.5 %
